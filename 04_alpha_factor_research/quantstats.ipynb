# %%
# https://github.com/ranaroussi/quantstats

# %matplotlib inline
import quantstats as qs

# extend pandas functionality with metrics, etc.
qs.extend_pandas()

# %%
# fetch the daily returns for a stock
stock = qs.utils.download_returns('BTC')

# %%
# show sharpe ratio
qs.stats.sharpe(stock)
# Out:
# -0.8221368245793115

# %%
# or using extend_pandas() :)
stock.sharpe()
# Out:
# -0.8221368245793115

# %%
qs.reports.full(stock, "SPY")
# Out:
# <h4>Performance Metrics</h4>
#                            Strategy    Benchmark
# -------------------------  ----------  -----------
# Start Period               2020-10-01  2020-10-01
# End Period                 2021-06-28  2021-06-28
# Risk-Free Rate             0.0%        0.0%
# Time in Market             79.0%       100.0%
#
# Cumulative Return          -0.89%      28.61%
# CAGR%                      -1.2%       40.51%
#
# Sharpe                     -0.82       2.42
# Sortino                    -1.03       3.68
# Sortino/√2                 -0.73       2.6
#
# Max Drawdown               -1.68%      -7.35%
# Longest DD Days            175         27
# Volatility (ann.)          1.46%       14.53%
# R^2                        0.03        0.03
# Calmar                     -0.72       5.51
# Skew                       -1.53       -0.44
# Kurtosis                   10.96       1.12
#
# Expected Daily %           -0.0%       0.14%
# Expected Monthly %         -0.1%       2.84%
# Expected Yearly %          -0.45%      13.41%
# Kelly Criterion            -20.55%     8.57%
# Risk of Ruin               0.0%        0.0%
# Daily Value-at-Risk        -0.16%      -1.37%
# Expected Shortfall (cVaR)  -0.16%      -1.37%
#
# Gain/Pain Ratio            -0.16       0.5
# Gain/Pain (1M)             -0.46       7.93
#
# Payoff Ratio               0.73        0.95
# Profit Factor              0.84        1.5
# Common Sense Ratio         0.67        1.72
# CPC Index                  0.3         0.79
# Tail Ratio                 0.8         1.15
# Outlier Win Ratio          26.15       1.47
# Outlier Loss Ratio         17.45       2.14
#
# MTD                        0.0%        1.77%
# 3M                         0.48%       7.95%
# 6M                         -0.92%      16.22%
# YTD                        -1.04%      14.71%
# 1Y                         -0.89%      28.61%
# 3Y (ann.)                  -1.2%       40.51%
# 5Y (ann.)                  -1.2%       40.51%
# 10Y (ann.)                 -1.2%       40.51%
# All-time (ann.)            -1.2%       40.51%
#
# Best Day                   0.31%       2.42%
# Worst Day                  -0.62%      -3.42%
# Best Month                 0.38%       10.88%
# Worst Month                -0.87%      -2.49%
# Best Year                  0.15%       14.71%
# Worst Year                 -1.04%      12.12%
#
# Avg. Drawdown              -0.56%      -1.31%
# Avg. Drawdown Days         64          6
# Recovery Factor            -0.53       3.89
# Ulcer Index                inf         1.04
#
# Avg. Up Month              0.26%       5.13%
# Avg. Down Month            -0.3%       -1.76%
# Win Days %                 49.32%      55.38%
# Win Month %                50.0%       77.78%
# Win Quarter %              66.67%      100.0%
# Win Year %                 50.0%       100.0%
# Beta                       0.02        -
# Alpha                      -0.02       -
# None
# <h4>5 Worst Drawdowns</h4>
#         Start      Valley         End  Days  Max Drawdown  99% Max Drawdown
# 1  2021-01-04  2021-03-19  2021-06-28   175     -1.675100         -1.639655
# 2  2020-10-07  2020-11-10  2020-11-30    54     -0.389882         -0.374590
# 3  2020-12-01  2020-12-09  2020-12-28    27     -0.189909         -0.184114
# 4  2020-10-05  2020-10-05  2020-10-06     1     -0.004997          0.000000
# <h4>Strategy Visualization</h4>
